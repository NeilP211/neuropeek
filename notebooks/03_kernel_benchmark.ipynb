# %% [markdown]
# # NeuroPeek Triton kernel benchmark (Colab T4)
#
# Clones the repo, installs Triton, runs `scripts/bench_kernel.py`, prints results. Target speedup: 1.5-3x over PyTorch eager.

# %%
# !git clone https://github.com/NeilP211/neuropeek.git
# %cd neuropeek
# !pip install -e . triton

# %%
# !python scripts/bench_kernel.py

# %%
import json
results = json.load(open('results/kernel_benchmark.json'))
for r in results:
    print(r)

# %% [markdown]
# Download `results/kernel_benchmark.json` and commit it back to the repo.
